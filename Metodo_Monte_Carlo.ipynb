# %% [markdown]
# <a href="https://colab.research.google.com/github/noemigarcia27/SImulacion-II/blob/main/Metodo_Monte_Carlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sympy

# %% [markdown]
# *4/sept/2025*
# # Método de Monte Carlo
# **a) Acierto y error **

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd

def g(x):
  return np.sqrt(np.arctan(x))

print(g(1))
aciertos=0
N=1000

X=np.linspace(0,1,100)
Y=g(X)
plt.plot(X,Y)
for i in range(N):  #generamos los pares aleatorios
  x=rd.random()
  y=rd.random()
  if y<=g(x): #cuantos caen debajo de la curva
    plt.scatter(x,y,color="blue")
    aciertos+=1 #vamos contando los puntos que caen debajo de la curva
  else:
    plt.scatter(x,y,color="red")

aciertos

I=aciertos/N #el numero de aciertos entre el total de los puntos
# Out:
# 0.8862269254527579

# %%
print(I)
# Out:
# 0.617

# %% [markdown]
# *5/sept/2025*

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd

# %%
def g(x):
  return np.sqrt(np.arctan(x))

# %%
def estimacion(N):
  lista=[]
  aciertos=0
  X=np.linspace(0,1,100)
  Y=g(X)
  plt.plot(X,Y)
  for i in range(N):
    x = rd.random()
    y = rd.random()
    if y <= g(x):
      plt.scatter(x,y,color="blue")
      aciertos += 1
    else:
      plt.scatter(x,y,color="red")
  I=aciertos/i+1
  lista.append(I)
  return lista

# %%
L=estimacion(1000)

# %%
plt.plot(L)

# %% [markdown]
# *11/sept/2025*
#
# # Método Monte Carlo Crudo

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd

# %% [markdown]
# La funcion que vamos a utilizar es
# g(x) = √arctan(x) dx

# %%
def g(x):
  return np.sqrt(np.arctan(x))

# %% [markdown]
# Paso 1 y Paso 3. (el paso 2 no es necesario porque la integral va de 0 a 1 )

# %%
def mc_crudo(N):
  lista=[]
  for i in range(N):
    u=rd.random()
    lista.append(g(u))
  return np.mean(lista)
print(mc_crudo(10))
# Out:
# 0.6935660609817007

# %%
L=[]
for i in range(1000):
  x=mc_crudo(i)
  L.append(x)
# Out:
# /usr/local/lib/python3.12/dist-packages/numpy/_core/fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.12/dist-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)

# %%
plt.plot(L)
