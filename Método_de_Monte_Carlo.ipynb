# %% [markdown]
# <a href="https://colab.research.google.com/github/noemigarcia27/SImulacion-II/blob/main/M%C3%A9todo_de_Monte_Carlo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sympy

# %% [markdown]
# # Método de Monte Carlo
# **a) Acierto y error **

# %%
import numpy as np
import matplotlib.pyplot as plt
import random as rd

def g(x):
  return np.sqrt(np.arctan(x))

print(g(1))
aciertos=0
N=1000

X=np.linspace(0,1,100)
Y=g(X)
plt.plot(X,Y)
for i in range(N):  #generamos los pares aleatorios
  x=rd.random()
  y=rd.random()
  if y<=g(x): #cuantos caen debajo de la curva
    plt.scatter(x,y,color="blue")
    aciertos+=1 #vamos contando los puntos que caen debajo de la curva
  else:
    plt.scatter(x,y,color="red")

aciertos

I=aciertos/N #el numero de aciertos entre el total de los puntos
# Out:
# 0.8862269254527579

# %%
print(I)
# Out:
# 0.656
